# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
while project_root.name != "big_data_assignment" and project_root.parent != project_root:
    project_root = project_root.parent

project_root_str = str(project_root)
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)

print("Using project root:", project_root)
print("Ensured project root on sys.path")

# %% [markdown]
# ### Environment setup
#
# Before running this notebook, install the project dependencies in a terminal from the project root (`big_data_assignment`):
#
# ```bash
# cd ~/Desktop/Big-Data/big_data_assignment
# pip install -r requirements.txt
# ```
#
# After installing, restart the Jupyter kernel and re-run the first environment cell.

# %%
# %pip install matplotlib pandas plotly networkx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 9.4 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import pandas as pd

# %%
#converting directing.json file first 
with open('directing.json', encoding='utf-8-sig') as file: 
    df = pd.read_json(file)

# Print the JSON structure
df.to_csv('directing.csv', encoding='utf-8', index=False)

# %%
df = pd.read_json('directing.json')

#if the json file is nested
# df = pd.json_normalize(df)

print(df)
# Out:
#            movie   director
# 0      tt0003740  nm0665163
# 1      tt0008663  nm0803705
# 2      tt0009369  nm0428059
# 3      tt0009369  nm0949648
# 4      tt0010307  nm0304098
# ...          ...        ...
# 11157  tt9850344  nm0284774
# 11158  tt9850386  nm0550881
# 11159  tt9900782  nm7992231
# 11160  tt9904802  nm0052054
# 11161  tt9911196  nm0631590
#
# [11162 rows x 2 columns]

# %% [markdown]
# ### Converting writing.json to csv

# %%
#converting directing.json file first 
with open('writing.json', encoding='utf-8-sig') as file_w: 
    df_w = pd.read_json(file_w)

# Print the JSON structure
df_w.to_csv('writing.csv', encoding='utf-8', index=False)

# %%
print(df_w)
# Out:
#            movie     writer
# 0      tt0003740  nm0195339
# 1      tt0003740  nm0515385
# 2      tt0003740  nm0665163
# 3      tt0003740  nm0758215
# 4      tt0008663  nm0406585
# ...          ...        ...
# 22423  tt9904802  nm0942647
# 22424  tt9904802  nm3853396
# 22425  tt9911196  nm2063122
# 22426  tt9911196  nm0277932
# 22427  tt9911196  nm3547655
#
# [22428 rows x 2 columns]
